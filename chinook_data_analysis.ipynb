# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('data1.csv')
df2 = pd.read_csv('data2.csv')
df3 = pd.read_csv('data3.csv')
df4 = pd.read_csv('data4.csv')

# %%
df1
# Out:
#    ArtistId                          Name  songs
# 0        22                  Led Zeppelin    114
# 1       150                            U2    112
# 2        58                   Deep Purple     92
# 3        90                   Iron Maiden     81
# 4       118                     Pearl Jam     54
# 5       152                     Van Halen     52
# 6        51                         Queen     45
# 7       142            The Rolling Stones     41
# 8        76  Creedence Clearwater Revival     40
# 9        52                          Kiss     35

# %%
plt.figure(figsize=(7,7))
plt.barh(df1.Name,df1.songs);
plt.title('Who is writing the rock music?',fontsize=18)
plt.ylabel('Name',fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Number of Songs',fontsize=14)
plt.show()

# %%
df2.head()
# Out:
#                           Name  Milliseconds  Miuntes
# 0       Occupation / Precipice       5286953    88.12
# 1      Through a Looking Glass       5088838    84.81
# 2  Greetings from Earth, Pt. 1       2960293    49.34
# 3      The Man With Nine Lives       2956998    49.28
# 4  Battlestar Galactica, Pt. 2       2956081    49.27

# %%
df2['Miuntes']= df2['Miuntes'].apply(lambda x: round(x,2))

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df2.Miuntes)
plt.title('Length distribution of the long tracks',fontsize=18)
plt.xticks(fontsize=14)
plt.xlabel('Minutes',fontsize=14)
plt.show()
# Out:
# C:\Users\Ahmed said\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df2.Miuntes.min()
# Out:
# 6.56

# %%
df3.head()
# Out:
#    purchases    country                name  genreid
# 0          9  Argentina                Rock        1
# 1          9  Argentina  Alternative & Punk        4
# 2         22  Australia                Rock        1
# 3         15    Austria                Rock        1
# 4         21    Belgium                Rock        1

# %%
df3.country.unique()
# Out:
# array(['Argentina', 'Australia', 'Austria', 'Belgium', 'Brazil', 'Canada',
#        'Chile', 'Czech Republic', 'Denmark', 'Finland', 'France',
#        'Germany', 'Hungary', 'India', 'Ireland', 'Italy', 'Netherlands',
#        'Norway', 'Poland', 'Portugal', 'Spain', 'Sweden', 'USA',
#        'United Kingdom'], dtype=object)

# %%
ndf=df3.iloc[:,1:3]

# %%
ndf.to_csv('map.csv',index=False)

# %%
plt.figure(figsize=(15,8))
hbars =plt.barh(df4.full_name,df4.TotalSpent)
plt.bar_label(hbars,labels=df4.country.tolist())
plt.title('the customer that has spent the most on music for each country',fontsize=18)
plt.ylabel('Customer Name',fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim([20,60])
plt.xlabel('Total spent',fontsize=14)
plt.show()

# %%
df4['full_name']=df4.FirstName + ' ' + df4.LastName

# %%
df4.full_name[0]
# Out:
# 'Diego Gutiérrez'

# %%
type(df4['full_name'])
# Out:
# pandas.core.series.Series

# %%
df4['full_name']
# Out:
# 'Mark Taylor'

# %%
df5 =pd.read_csv('data5.csv')
df5.head()
# Out:
#           name  AmountSpent  customerId firstName   lastName
# 0  Iron Maiden        17.82          55      Mark     Taylor
# 1  Iron Maiden        15.84          35  Madalena    Sampaio
# 2  Iron Maiden        13.86          36    Hannah  Schneider
# 3  Iron Maiden        13.86          16     Frank     Harris
# 4  Iron Maiden         8.91          27   Patrick       Gray

# %%
df5['full_name']=df5.firstName +' '+df5.lastName
df5.head()
# Out:
#           name  AmountSpent  customerId firstName   lastName         full_name
# 0  Iron Maiden        17.82          55      Mark     Taylor       Mark Taylor
# 1  Iron Maiden        15.84          35  Madalena    Sampaio  Madalena Sampaio
# 2  Iron Maiden        13.86          36    Hannah  Schneider  Hannah Schneider
# 3  Iron Maiden        13.86          16     Frank     Harris      Frank Harris
# 4  Iron Maiden         8.91          27   Patrick       Gray      Patrick Gray

# %%
plt.figure(figsize=(10,8))
plt.barh(df5.iloc[0:10,:].full_name,df5.iloc[0:10,:].AmountSpent);
plt.title('highest 10 customers spent the most on Iron Maiden.',fontsize=18)
plt.xlabel('Amount spent',fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel('Name',fontsize=14)
plt.show()
